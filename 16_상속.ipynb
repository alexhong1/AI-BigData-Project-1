# %% [markdown]
# # 1. 상속

# %% [markdown]
# - 기존의 정의해둔 클래스의 기능을 그대로 물려받음
# - 기존 클래스에 기능 일부를 추가하거나, 변경하여 새로운 클래스를 정의함
# - 코드를 재사용할 수 있게 됨
# - 안정적이고 유지보수에 용이함
# - 상속을 받고자 하는 대상인 기존 클래스를 부모, parent, super, base 클래스라고 부름
# - 상속을 받는 새로운 클래스는 자식, child, sub 클래스라고 부름

# %%
class Animal:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def eat(self, food):
    print("{}는 {}를 먹습니다".format(self.name, food))

  def sleep(self, hour):
    print("{}는 {}시간 동안 잡니다".format(self.name, hour))

# %%
animal = Animal('류호근', 22)
animal.eat('잡채')
animal.sleep(4)
# Out:
# 류호근는 잡채를 먹습니다
# 류호근는 4시간 동안 잡니다

# %%
class Dog(Animal): # Animal 클래스를 상속
  pass

# %%
Jin = Dog('진순이', 1)
Jin.eat('영양식')
Jin.sleep(8)
# Out:
# 진순이는 영양식를 먹습니다
# 진순이는 8시간 동안 잡니다

# %% [markdown]
# # 2. 메소드 오버라이딩
# - 부모 클래스의 method를 재정의
# - 자식 클래스의 인스턴스로 호출시, 재정의된 메소드가 호출됨

# %%
class Animal:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def eat(self, food):
    print("{}는 {}를 먹습니다".format(self.name, food))

  def sleep(self, hour):
    print("{}는 {}시간 동안 잡니다".format(self.name, hour))

# %%
class Dog(Animal):
  def eat(self, food): # 메소드 오버라이딩
    print(f'{self.name}는 {food}를  아주 맛나게 먹는다.')

# %%
Jin = Dog('진순이', 1)
Jin.eat('영양식')
Jin.sleep(8)
# Out:
# 진순이는 영양식를  아주 맛나게 먹는다.
# 진순이는 8시간 동안 잡니다

# %% [markdown]
# # 3. 다중 상속

# %%
class Animal:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def eat(self, food):
    print("{}는 {}를 먹습니다".format(self.name, food))

  def sleep(self, hour):
    print("{}는 {}시간 동안 잡니다".format(self.name, hour))

# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def study(self, hour):
    print("{}는 {}시간 동안 공부합니다.".format(self.name, hour))

# %%
class RyuHogeun(Animal, Human):
  pass

# %%
Ryu = RyuHogeun('류호근', 22)
Ryu.eat('치킨')
# Out:
# 류호근는 치킨를 먹습니다

# %%
Ryu.sleep(12)
# Out:
# 류호근는 12시간 동안 잡니다

# %%
Ryu.study(3)
# Out:
# 류호근는 3시간 동안 공부합니다.
