# %% [markdown]
# # 1. input 함수

# %% [markdown]
# - 사용자에게 데이터를 입력 받을 수 있는 함수
# - 데이터를 문자형으로 입력

# %%
name = input()
print(name)
# Out:
# 류호근
# 류호근

# %%
name = input('이름을 입력해보아요 : ')
print('%s님! 이름을 참 멋지네요!' % name)
# Out:
# 이름을 입력해보아요 : 류호근 류호근 류호근
# 류호근 류호근 류호근님! 이름을 참 멋지네요!

# %%
# split() : 매개변수로 전달된 문자를 기준으로 데이터를 나눠서 저장
name, age, height = input('이름, 나이, 키를 스페이스 바를 기준으로 나눠서 입력하세요 : ').split(' ')
print('{0}님의 나이는 {1}살이며, 키는 {2}cm 입니다.'.format(name, age, height))
# Out:
# 이름, 나이, 키를 스페이스 바를 기준으로 나눠서 입력하세요 : 류호근 22 182
# 류호근님의 나이는 22살이며, 키는 182cm 입니다.

# %%
name, age, height = input('이름, 나이, 키를 /를 기준으로 나눠서 입력하세요 : ').split('/')
print('{0}님의 나이는 {1}살이며, 키는 {2}cm 입니다.'.format(name, age, height))
# Out:
# 이름, 나이, 키를 /를 기준으로 나눠서 입력하세요 : 류호근/22/182
# 류호근님의 나이는 22살이며, 키는 182cm 입니다.

# %% [markdown]
# ### 문제
# - 국어, 영어, 수학 점수를 입력받아 총점, 평균을 구하는 프로그램을 작성해보자.

# %%
# int() : 문자열을 숫자(정수)타입으로 변환
# num1 = '100'
# num2 = '50'
# print(int(num1) + int(num2))
# print(int(num1 + num2))

kor, eng, math = input('국어, 영어, 수학점수를 입력하세요.').split(' ')

# print('총점 : ', int(kor) + int(eng) + int(math)) # 각 문자를 숫자로 변환 후 덧셈

total = int(kor) + int(eng) + int(math)
avg = total / 3

# 순서대로 인덱스 번호를 넣고 싶으면 굳이 적지 않아도 된다.
print('총점 : {}, 평균 : {}'.format(total, avg))
# Out:
# 국어, 영어, 수학점수를 입력하세요.50 40 80
# 총점 : 170, 평균 : 56.666666666666664

# %%
kor, eng, math = input('국어, 영어, 수학점수를 입력하세요.').split(' ')

total = int(kor) + int(eng) + int(math)
avg = total / 3

# print('총점 : {a}, 평균 : {b}'.format(a = int(kor) + int(eng) + int(math), b = total / 3))
print(f'총점 : {total}, 평균 : {avg}')
# Out:
# 국어, 영어, 수학점수를 입력하세요.50 40 30
# 총점 : 120, 평균 : 40.0

# %% [markdown]
# # 2. map 함수

# %% [markdown]
# - 미리 타입을 지정하여 입력 받는 함수

# %%
kor, eng, math = map(int, input('국어, 영어, 수학점수를 입력하세요.').split(' '))
print('총점 : ', kor + eng + math)
# Out:
# 국어, 영어, 수학점수를 입력하세요.50 40 30
# 총점 :  120
